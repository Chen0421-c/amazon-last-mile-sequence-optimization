# %% [markdown]
# # 02 EDA Summary Analysis
#
# Run this notebook in Google Colab after `01_data_cleaning_pipeline.py` has generated cleaned CSV files. This step creates EDA summaries and plots only; it does not train a model.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !python 02_eda_summary_analysis.py \
  --input-dir /content/drive/MyDrive/dissertation/amazon_last_mile/processed_outputs \
  --output-dir /content/drive/MyDrive/dissertation/amazon_last_mile/processed_outputs/eda_outputs

# %% [markdown]
# If transition merges are too large for the Colab runtime, sample transitions before the merge-heavy EDA sections:

# %%
# !python 02_eda_summary_analysis.py \
  --sample-frac 0.25 \
  --input-dir /content/drive/MyDrive/dissertation/amazon_last_mile/processed_outputs \
  --output-dir /content/drive/MyDrive/dissertation/amazon_last_mile/processed_outputs/eda_outputs
