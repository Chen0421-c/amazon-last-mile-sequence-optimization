# %% [markdown]
# # 01 Data Cleaning Pipeline
#
# Run this notebook in Google Colab to create cleaned CSV outputs for the Amazon Last Mile Routing Research Challenge dataset. This step is for data cleaning and EDA preparation only; it does not train a model.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !python 01_data_cleaning_pipeline.py \
  --data-root /content/drive/MyDrive/dissertation/amazon_last_mile \
  --output-dir /content/drive/MyDrive/dissertation/amazon_last_mile/processed_outputs
