# %% [markdown]
# # 02 Data Quality and Outlier Analysis
#
# Run this notebook after the first-round cleaning pipeline has generated CSV files. This second-round step checks data reliability, route validity, outliers, package consistency, and travel-time integrity only. It does not train a model.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !python 02_data_quality_and_outlier_analysis.py \
  --input-dir /content/drive/MyDrive/dissertation/amazon_last_mile/processed_outputs \
  --data-root /content/drive/MyDrive/dissertation/amazon_last_mile \
  --output-dir /content/drive/MyDrive/dissertation/amazon_last_mile/processed_outputs/quality_outputs

# %% [markdown]
# For a quick travel-time integrity smoke test, limit the number of routes streamed from `travel_times.json`:

# %%
# !python 02_data_quality_and_outlier_analysis.py \
  --max-routes 100 \
  --input-dir /content/drive/MyDrive/dissertation/amazon_last_mile/processed_outputs \
  --data-root /content/drive/MyDrive/dissertation/amazon_last_mile \
  --output-dir /content/drive/MyDrive/dissertation/amazon_last_mile/processed_outputs/quality_outputs
