# %% [markdown]
# # 04 Transition Feature EDA
#
# Run this notebook after final cleaned transition/travel-time CSVs are available. This step creates transition-level feature EDA outputs only and does not train a model.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !python 04_transition_feature_eda.py \
  --processed-dir /content/drive/MyDrive/dissertation/amazon_last_mile/processed_outputs \
  --final-cleaned-dir /content/drive/MyDrive/dissertation/amazon_last_mile/processed_outputs/final_cleaned \
  --output-dir /content/drive/MyDrive/dissertation/amazon_last_mile/processed_outputs/feature_eda_outputs

# %% [markdown]
# For a smaller smoke test, cap the transition feature sample:

# %%
# !python 04_transition_feature_eda.py \
  --max-rows 25000 \
  --processed-dir /content/drive/MyDrive/dissertation/amazon_last_mile/processed_outputs \
  --final-cleaned-dir /content/drive/MyDrive/dissertation/amazon_last_mile/processed_outputs/final_cleaned \
  --output-dir /content/drive/MyDrive/dissertation/amazon_last_mile/processed_outputs/feature_eda_outputs
