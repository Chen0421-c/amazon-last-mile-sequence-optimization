# %% [markdown]
# # 03 Travel Time Multi-Source Check
#
# Run this notebook after first-round cleaning has generated `actual_transitions.csv`. It checks actual transition travel times across training build, training apply, and evaluation apply travel-time JSON files without training a model.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !python 03_travel_time_multisource_check.py \
  --input-dir /content/drive/MyDrive/dissertation/amazon_last_mile/processed_outputs \
  --data-root /content/drive/MyDrive/dissertation/amazon_last_mile \
  --output-dir /content/drive/MyDrive/dissertation/amazon_last_mile/processed_outputs/travel_time_multisource_outputs

# %% [markdown]
# For a quick smoke test, limit the number of route IDs checked:

# %%
# !python 03_travel_time_multisource_check.py \
  --max-routes 100 \
  --input-dir /content/drive/MyDrive/dissertation/amazon_last_mile/processed_outputs \
  --data-root /content/drive/MyDrive/dissertation/amazon_last_mile \
  --output-dir /content/drive/MyDrive/dissertation/amazon_last_mile/processed_outputs/travel_time_multisource_outputs
